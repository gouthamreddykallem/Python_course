# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

warnings.filterwarnings('ignore')

# %%
dataset_path = r'../index.csv'

# %%
rawData = pd.read_csv(dataset_path)
rawData
# Out:
#      Year  Month  Day  Federal Funds Target Rate  Federal Funds Upper Target  \
# 0    1954      7    1                        NaN                         NaN
# 1    1954      8    1                        NaN                         NaN
# 2    1954      9    1                        NaN                         NaN
# 3    1954     10    1                        NaN                         NaN
# 4    1954     11    1                        NaN                         NaN
# ..    ...    ...  ...                        ...                         ...
# 899  2016     12   14                        NaN                        0.75
# 900  2017      1    1                        NaN                        0.75
# 901  2017      2    1                        NaN                        0.75
# 902  2017      3    1                        NaN                        0.75
# 903  2017      3   16                        NaN                        1.00
#
#      Federal Funds Lower Target  Effective Federal Funds Rate  \
# 0                           NaN                          0.80
# 1                           NaN                          1.22
# 2                           NaN                          1.06
# 3                           NaN                          0.85
# 4                           NaN                          0.83
# ..                          ...                           ...
# 899                        0.50                           NaN
# 900                        0.50                          0.65
# 901                        0.50                          0.66
# 902                        0.50                           NaN
# 903                        0.75                           NaN
#
#      Real GDP (Percent Change)  Unemployment Rate  Inflation Rate
# 0                          4.6                5.8             NaN
# 1                          NaN                6.0             NaN
# 2                          NaN                6.1             NaN
# 3                          8.0                5.7             NaN
# 4                          NaN                5.3             NaN
# ..                         ...                ...             ...
# 899                        NaN                NaN             NaN
# 900                        NaN                4.8             2.3
# 901                        NaN                4.7             2.2
# 902                        NaN                NaN             NaN
# 903                        NaN                NaN             NaN
#
# [904 rows x 10 columns]

# %% [markdown]
# <h1>Data preprocessing and cleaning</h1>

# %%
rawData.isnull().sum()

# Looks like there are so many null values
# Out:
# Year                              0
# Month                             0
# Day                               0
# Federal Funds Target Rate       442
# Federal Funds Upper Target      801
# Federal Funds Lower Target      801
# Effective Federal Funds Rate    152
# Real GDP (Percent Change)       654
# Unemployment Rate               152
# Inflation Rate                  194
# dtype: int64

# %%
dataframe = rawData.fillna(method='ffill')

# %%
dataframe
# Out:
#      Year  Month  Day  Federal Funds Target Rate  Federal Funds Upper Target  \
# 0    1954      7    1                        NaN                         NaN
# 1    1954      8    1                        NaN                         NaN
# 2    1954      9    1                        NaN                         NaN
# 3    1954     10    1                        NaN                         NaN
# 4    1954     11    1                        NaN                         NaN
# ..    ...    ...  ...                        ...                         ...
# 899  2016     12   14                        1.0                        0.75
# 900  2017      1    1                        1.0                        0.75
# 901  2017      2    1                        1.0                        0.75
# 902  2017      3    1                        1.0                        0.75
# 903  2017      3   16                        1.0                        1.00
#
#      Federal Funds Lower Target  Effective Federal Funds Rate  \
# 0                           NaN                          0.80
# 1                           NaN                          1.22
# 2                           NaN                          1.06
# 3                           NaN                          0.85
# 4                           NaN                          0.83
# ..                          ...                           ...
# 899                        0.50                          0.54
# 900                        0.50                          0.65
# 901                        0.50                          0.66
# 902                        0.50                          0.66
# 903                        0.75                          0.66
#
#      Real GDP (Percent Change)  Unemployment Rate  Inflation Rate
# 0                          4.6                5.8             NaN
# 1                          4.6                6.0             NaN
# 2                          4.6                6.1             NaN
# 3                          8.0                5.7             NaN
# 4                          8.0                5.3             NaN
# ..                         ...                ...             ...
# 899                        1.9                4.7             2.2
# 900                        1.9                4.8             2.3
# 901                        1.9                4.7             2.2
# 902                        1.9                4.7             2.2
# 903                        1.9                4.7             2.2
#
# [904 rows x 10 columns]

# %%
dataframe.isnull().sum()
# Considerablly reduces the nulls
# Out:
# Year                              0
# Month                             0
# Day                               0
# Federal Funds Target Rate       339
# Federal Funds Upper Target      801
# Federal Funds Lower Target      801
# Effective Federal Funds Rate      0
# Real GDP (Percent Change)         0
# Unemployment Rate                 0
# Inflation Rate                   42
# dtype: int64

# %%
(dataframe.isnull().sum()/(len(rawData)))*100
# Out:
# Year                             0.000000
# Month                            0.000000
# Day                              0.000000
# Federal Funds Target Rate       37.500000
# Federal Funds Upper Target      88.606195
# Federal Funds Lower Target      88.606195
# Effective Federal Funds Rate     0.000000
# Real GDP (Percent Change)        0.000000
# Unemployment Rate                0.000000
# Inflation Rate                   4.646018
# dtype: float64

# %%
dataframe = dataframe.drop(['Federal Funds Upper Target','Federal Funds Lower Target'], axis = 1)
# dataframe = dataframe.fillna(lrData.mean())
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          904 non-null    int64
#  1   Month                         904 non-null    int64
#  2   Day                           904 non-null    int64
#  3   Federal Funds Target Rate     565 non-null    float64
#  4   Effective Federal Funds Rate  904 non-null    float64
#  5   Real GDP (Percent Change)     904 non-null    float64
#  6   Unemployment Rate             904 non-null    float64
#  7   Inflation Rate                862 non-null    float64
# dtypes: float64(5), int64(3)
# memory usage: 56.6 KB

# %%
dataframe
# Out:
#      Year  Month  Day  Federal Funds Target Rate  \
# 0    1954      7    1                        NaN
# 1    1954      8    1                        NaN
# 2    1954      9    1                        NaN
# 3    1954     10    1                        NaN
# 4    1954     11    1                        NaN
# ..    ...    ...  ...                        ...
# 899  2016     12   14                        1.0
# 900  2017      1    1                        1.0
# 901  2017      2    1                        1.0
# 902  2017      3    1                        1.0
# 903  2017      3   16                        1.0
#
#      Effective Federal Funds Rate  Real GDP (Percent Change)  \
# 0                            0.80                        4.6
# 1                            1.22                        4.6
# 2                            1.06                        4.6
# 3                            0.85                        8.0
# 4                            0.83                        8.0
# ..                            ...                        ...
# 899                          0.54                        1.9
# 900                          0.65                        1.9
# 901                          0.66                        1.9
# 902                          0.66                        1.9
# 903                          0.66                        1.9
#
#      Unemployment Rate  Inflation Rate
# 0                  5.8             NaN
# 1                  6.0             NaN
# 2                  6.1             NaN
# 3                  5.7             NaN
# 4                  5.3             NaN
# ..                 ...             ...
# 899                4.7             2.2
# 900                4.8             2.3
# 901                4.7             2.2
# 902                4.7             2.2
# 903                4.7             2.2
#
# [904 rows x 8 columns]

# %%
# Combining Year, Month and Day to from Date
dataframe['Date'] = ''
for index, row in dataframe.iterrows():
    dataframe['Date'][index] = str(dataframe['Year'][index])+"/"+str(dataframe['Month'][index])+"/"+str(dataframe['Day'][index])

# %%
dataframe["Date"] = pd.to_datetime(dataframe["Date"])
dataframe
# Out:
#      Year  Month  Day  Federal Funds Target Rate  \
# 0    1954      7    1                        NaN
# 1    1954      8    1                        NaN
# 2    1954      9    1                        NaN
# 3    1954     10    1                        NaN
# 4    1954     11    1                        NaN
# ..    ...    ...  ...                        ...
# 899  2016     12   14                        1.0
# 900  2017      1    1                        1.0
# 901  2017      2    1                        1.0
# 902  2017      3    1                        1.0
# 903  2017      3   16                        1.0
#
#      Effective Federal Funds Rate  Real GDP (Percent Change)  \
# 0                            0.80                        4.6
# 1                            1.22                        4.6
# 2                            1.06                        4.6
# 3                            0.85                        8.0
# 4                            0.83                        8.0
# ..                            ...                        ...
# 899                          0.54                        1.9
# 900                          0.65                        1.9
# 901                          0.66                        1.9
# 902                          0.66                        1.9
# 903                          0.66                        1.9
#
#      Unemployment Rate  Inflation Rate       Date
# 0                  5.8             NaN 1954-07-01
# 1                  6.0             NaN 1954-08-01
# 2                  6.1             NaN 1954-09-01
# 3                  5.7             NaN 1954-10-01
# 4                  5.3             NaN 1954-11-01
# ..                 ...             ...        ...
# 899                4.7             2.2 2016-12-14
# 900                4.8             2.3 2017-01-01
# 901                4.7             2.2 2017-02-01
# 902                4.7             2.2 2017-03-01
# 903                4.7             2.2 2017-03-16
#
# [904 rows x 9 columns]

# %% [markdown]
# <h1>EDA</h1>

# %%
dataframe.describe().T
# Out:
#                               count         mean        std      min  \
# Year                          904.0  1986.680310  17.172843  1954.00
# Month                         904.0     6.598451   3.471963     1.00
# Day                           904.0     3.598451   6.791079     1.00
# Federal Funds Target Rate     565.0     4.809181   2.927770     1.00
# Effective Federal Funds Rate  904.0     5.120697   3.514298     0.07
# Real GDP (Percent Change)     904.0     3.076438   3.498193   -10.00
# Unemployment Rate             904.0     6.015265   1.558206     3.40
# Inflation Rate                862.0     3.710209   2.384286     0.60
#
#                                     25%      50%        75%     max
# Year                          1973.0000  1987.50  2001.0000  2017.0
# Month                            4.0000     7.00    10.0000    12.0
# Day                              1.0000     1.00     1.0000    31.0
# Federal Funds Target Rate        1.7500     5.25     6.8750    11.5
# Effective Federal Funds Rate     2.7025     4.94     7.1225    19.1
# Real GDP (Percent Change)        1.4000     3.10     4.8000    16.5
# Unemployment Rate                4.9000     5.70     7.1000    10.8
# Inflation Rate                   2.1000     2.90     4.6000    13.6

# %%
cols = dataframe.select_dtypes(include=np.number).columns.tolist()


for col in cols:
    print(col)
    print('Skew :', round(dataframe[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    dataframe[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=dataframe[col])
    plt.show()
# Out:
# Year
# Skew : -0.14
# Month
# Skew : -0.03
# Day
# Skew : 2.67
# Federal Funds Target Rate
# Skew : 0.17
# Effective Federal Funds Rate
# Skew : 0.82
# Real GDP (Percent Change)
# Skew : -0.26
# Unemployment Rate
# Skew : 0.78
# Inflation Rate
# Skew : 1.66

# %%
sns.distplot(dataframe["Unemployment Rate"], axlabel="Unemployment Rate");

# %%
sns.distplot(dataframe["Inflation Rate"], axlabel="Inflation Rate");

# %%
corr_matrix = dataframe.corr()
corr_matrix
# Out:
#                                   Year     Month       Day  \
# Year                          1.000000 -0.012482  0.154278
# Month                        -0.012482  1.000000  0.013726
# Day                           0.154278  0.013726  1.000000
# Federal Funds Target Rate    -0.870362  0.033932  0.235332
# Effective Federal Funds Rate -0.265682  0.014026  0.119140
# Real GDP (Percent Change)    -0.212437 -0.057083 -0.025669
# Unemployment Rate             0.159131  0.027295  0.037700
# Inflation Rate               -0.302650  0.003475 -0.025515
#
#                               Federal Funds Target Rate  \
# Year                                          -0.870362
# Month                                          0.033932
# Day                                            0.235332
# Federal Funds Target Rate                      1.000000
# Effective Federal Funds Rate                   0.994968
# Real GDP (Percent Change)                      0.310327
# Unemployment Rate                              0.033758
# Inflation Rate                                 0.826370
#
#                               Effective Federal Funds Rate  \
# Year                                             -0.265682
# Month                                             0.014026
# Day                                               0.119140
# Federal Funds Target Rate                         0.994968
# Effective Federal Funds Rate                      1.000000
# Real GDP (Percent Change)                        -0.018920
# Unemployment Rate                                 0.097814
# Inflation Rate                                    0.769210
#
#                               Real GDP (Percent Change)  Unemployment Rate  \
# Year                                          -0.212437           0.159131
# Month                                         -0.057083           0.027295
# Day                                           -0.025669           0.037700
# Federal Funds Target Rate                      0.310327           0.033758
# Effective Federal Funds Rate                  -0.018920           0.097814
# Real GDP (Percent Change)                      1.000000          -0.040477
# Unemployment Rate                             -0.040477           1.000000
# Inflation Rate                                -0.164780           0.223702
#
#                               Inflation Rate
# Year                               -0.302650
# Month                               0.003475
# Day                                -0.025515
# Federal Funds Target Rate           0.826370
# Effective Federal Funds Rate        0.769210
# Real GDP (Percent Change)          -0.164780
# Unemployment Rate                   0.223702
# Inflation Rate                      1.000000

# %%
sns.heatmap(corr_matrix, cmap="coolwarm", vmax=1, vmin=-1, linewidths=.5, cbar_kws={"shrink": 0.75})
# Out:
# <Axes: >

# %%
sns.heatmap(corr_matrix, annot=True, cmap="crest")
# Out:
# <Axes: >

# %%
upperCorr = np.triu(corr_matrix, k=1)
columns = corr_matrix.columns
upper_corr_df = pd.DataFrame(upperCorr, columns=columns, index=columns)
upper_corr_df
# Out:
#                               Year     Month       Day  \
# Year                           0.0 -0.012482  0.154278
# Month                          0.0  0.000000  0.013726
# Day                            0.0  0.000000  0.000000
# Federal Funds Target Rate      0.0  0.000000  0.000000
# Effective Federal Funds Rate   0.0  0.000000  0.000000
# Real GDP (Percent Change)      0.0  0.000000  0.000000
# Unemployment Rate              0.0  0.000000  0.000000
# Inflation Rate                 0.0  0.000000  0.000000
#
#                               Federal Funds Target Rate  \
# Year                                          -0.870362
# Month                                          0.033932
# Day                                            0.235332
# Federal Funds Target Rate                      0.000000
# Effective Federal Funds Rate                   0.000000
# Real GDP (Percent Change)                      0.000000
# Unemployment Rate                              0.000000
# Inflation Rate                                 0.000000
#
#                               Effective Federal Funds Rate  \
# Year                                             -0.265682
# Month                                             0.014026
# Day                                               0.119140
# Federal Funds Target Rate                         0.994968
# Effective Federal Funds Rate                      0.000000
# Real GDP (Percent Change)                         0.000000
# Unemployment Rate                                 0.000000
# Inflation Rate                                    0.000000
#
#                               Real GDP (Percent Change)  Unemployment Rate  \
# Year                                          -0.212437           0.159131
# Month                                         -0.057083           0.027295
# Day                                           -0.025669           0.037700
# Federal Funds Target Rate                      0.310327           0.033758
# Effective Federal Funds Rate                  -0.018920           0.097814
# Real GDP (Percent Change)                      0.000000          -0.040477
# Unemployment Rate                              0.000000           0.000000
# Inflation Rate                                 0.000000           0.000000
#
#                               Inflation Rate
# Year                               -0.302650
# Month                               0.003475
# Day                                -0.025515
# Federal Funds Target Rate           0.826370
# Effective Federal Funds Rate        0.769210
# Real GDP (Percent Change)          -0.164780
# Unemployment Rate                   0.223702
# Inflation Rate                      0.000000

# %%
plt.rcParams["figure.autolayout"] = True
plt.bar(corr_matrix.columns, list(corr_matrix['Inflation Rate']))
plt.ylabel("Inflation Rate",fontsize=15)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Year'),
#   Text(1, 0, 'Month'),
#   Text(2, 0, 'Day'),
#   Text(3, 0, 'Federal Funds Target Rate'),
#   Text(4, 0, 'Effective Federal Funds Rate'),
#   Text(5, 0, 'Real GDP (Percent Change)'),
#   Text(6, 0, 'Unemployment Rate'),
#   Text(7, 0, 'Inflation Rate')])

# %%
plt.rcParams["figure.autolayout"] = True
plt.bar(corr_matrix.columns, list(corr_matrix['Unemployment Rate']))
plt.ylabel("Unemployment Rate",fontsize=15)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Year'),
#   Text(1, 0, 'Month'),
#   Text(2, 0, 'Day'),
#   Text(3, 0, 'Federal Funds Target Rate'),
#   Text(4, 0, 'Effective Federal Funds Rate'),
#   Text(5, 0, 'Real GDP (Percent Change)'),
#   Text(6, 0, 'Unemployment Rate'),
#   Text(7, 0, 'Inflation Rate')])

# %%
dataframe.hist()
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Month'}>,
#         <Axes: title={'center': 'Day'}>],
#        [<Axes: title={'center': 'Federal Funds Target Rate'}>,
#         <Axes: title={'center': 'Effective Federal Funds Rate'}>,
#         <Axes: title={'center': 'Real GDP (Percent Change)'}>],
#        [<Axes: title={'center': 'Unemployment Rate'}>,
#         <Axes: title={'center': 'Inflation Rate'}>,
#         <Axes: title={'center': 'Date'}>]], dtype=object)

# %% [markdown]
# <h1>
#
# </h1>

# %%
plt.figure(figsize=(10,7))
plt.plot(dataframe['Date'],dataframe['Federal Funds Target Rate'])
plt.xlabel("Time Frame",fontsize=22)
plt.ylabel("Federal Funds Rate",fontsize=22)
plt.show()
plt.close()

# %% [markdown]
# <h1>
# In the above graph we see 4 major dips
# </h1>
#
# <h2>
# First is in the 1980's
# </h2>
#
# <h2>
# Second is in the start of 1990's
# </h2>
#
# <h2>
# Third is in the 2001
# </h2>
#
#
# <h2>
# Fourth is in the 2008
# </h2>

# %% [markdown]
# <h1> Now lets try to analyze the historical pattern in 2008 financial crisis  </h1

# %%
data_in_2007 = dataframe[((dataframe['Year']>=2007) & (dataframe['Year']<=2009))]
data_in_2007.head()
# Out:
#      Year  Month  Day  Federal Funds Target Rate  \
# 768  2007      1    1                       5.25
# 769  2007      2    1                       5.25
# 770  2007      3    1                       5.25
# 771  2007      4    1                       5.25
# 772  2007      5    1                       5.25
#
#      Effective Federal Funds Rate  Real GDP (Percent Change)  \
# 768                          5.25                        0.2
# 769                          5.26                        0.2
# 770                          5.26                        0.2
# 771                          5.25                        3.1
# 772                          5.25                        3.1
#
#      Unemployment Rate  Inflation Rate       Date
# 768                4.6             2.7 2007-01-01
# 769                4.5             2.7 2007-02-01
# 770                4.4             2.5 2007-03-01
# 771                4.5             2.3 2007-04-01
# 772                4.4             2.2 2007-05-01

# %%
plt.figure(figsize=(10,7))
plt.plot(data_in_2007['Date'],data_in_2007['Federal Funds Target Rate'], label = 'Federal Funds Target Rate')
plt.plot(data_in_2007['Date'],data_in_2007['Unemployment Rate'], label ='Unemployment Rate')
plt.plot(data_in_2007['Date'],data_in_2007['Inflation Rate'], label = 'Inflation Rate')
plt.xlabel("Time Frame",fontsize=22)
plt.ylabel("Rates",fontsize=22)
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# In the years leading up to the crisis, the Federal Reserve lowered interest rates to stimulate economic activity after the dot-com bubble burst in the early 2000s. The low-interest rates encouraged borrowing and contributed to the housing bubble.
#
# The financial crisis led to a severe recession, causing businesses to cut jobs to cope with declining demand and financial difficulties. The unemployment rate surged as a result.
#
#
# The crisis initially led to deflationary pressures as asset prices, particularly housing, collapsed. However, central banks, including the Federal Reserve, implemented aggressive monetary policies to combat deflation and stimulate economic activity.

# %% [markdown]
# <h1> Over all comparision of the relationships between Federal Funds Target Rate, Inflation Rate, and Unemployment Rate </h1>

# %%
plt.figure(figsize=(10,7))
plt.plot(dataframe['Date'],dataframe['Federal Funds Target Rate'], label = 'Federal Funds Target Rate')
plt.plot(dataframe['Date'],dataframe['Unemployment Rate'], label ='Unemployment Rate')
plt.plot(dataframe['Date'],dataframe['Inflation Rate'], label = 'Inflation Rate')
plt.xlabel("Time Frame",fontsize=22)
plt.ylabel("Rates",fontsize=22)
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# Federal Funds Target Rate:
#
# Federal Funds Target Rate peaked in the early 1980s. In the 1990s and early 2000s, there was a period of relatively low-interest rates, which contributed to economic expansion but also played a role in the housing bubble that led to the 2008 financial crisis. Post-crisis, rates remained exceptionally low for an extended period to stimulate economic recovery.
#
#
#
# Unemployment Rate:
#
# The unemployment rate has varied over the decades. In the 1960s, it was generally low. The 1970s saw an increase, driven by factors like oil price shocks and economic recessions. The 1980s witnessed efforts to combat inflation, leading to a temporary rise in unemployment. The 1990s and early 2000s were marked by relatively low unemployment, but the 2008 financial crisis caused a significant spike in joblessness. Post-crisis, there was a gradual improvement in the labor market.
#
#
# Inflation Rate:
#
# Inflation in the 1960s and early 1970s was relatively moderate. However, the 1970s experienced high inflation due to factors like oil price shocks. The 1980s saw a deliberate effort by central banks to bring down inflation, which was largely successful. In the 1990s and early 2000s, inflation remained relatively low. The 2008 financial crisis initially led to deflationary pressures, but central banks implemented measures to prevent prolonged deflation.

# %% [markdown]
# <h1>Models to forecast Interest, Inflation, and
# Unemployment rates</h1>

# %%
#lrData = dataframe.drop(['Year', 'Month', 'Day'], axis=1)
#lrData = dataframe.drop(['Date'], axis=1)
lrData = dataframe
lrData
# Out:
#      Year  Month  Day  Federal Funds Target Rate  \
# 0    1954      7    1                        NaN
# 1    1954      8    1                        NaN
# 2    1954      9    1                        NaN
# 3    1954     10    1                        NaN
# 4    1954     11    1                        NaN
# ..    ...    ...  ...                        ...
# 899  2016     12   14                        1.0
# 900  2017      1    1                        1.0
# 901  2017      2    1                        1.0
# 902  2017      3    1                        1.0
# 903  2017      3   16                        1.0
#
#      Effective Federal Funds Rate  Real GDP (Percent Change)  \
# 0                            0.80                        4.6
# 1                            1.22                        4.6
# 2                            1.06                        4.6
# 3                            0.85                        8.0
# 4                            0.83                        8.0
# ..                            ...                        ...
# 899                          0.54                        1.9
# 900                          0.65                        1.9
# 901                          0.66                        1.9
# 902                          0.66                        1.9
# 903                          0.66                        1.9
#
#      Unemployment Rate  Inflation Rate       Date
# 0                  5.8             NaN 1954-07-01
# 1                  6.0             NaN 1954-08-01
# 2                  6.1             NaN 1954-09-01
# 3                  5.7             NaN 1954-10-01
# 4                  5.3             NaN 1954-11-01
# ..                 ...             ...        ...
# 899                4.7             2.2 2016-12-14
# 900                4.8             2.3 2017-01-01
# 901                4.7             2.2 2017-02-01
# 902                4.7             2.2 2017-03-01
# 903                4.7             2.2 2017-03-16
#
# [904 rows x 9 columns]

# %%
lrData = lrData.fillna(lrData.mean())

# %%
lrData.isnull().sum()
# Out:
# Year                            0
# Month                           0
# Day                             0
# Federal Funds Target Rate       0
# Effective Federal Funds Rate    0
# Real GDP (Percent Change)       0
# Unemployment Rate               0
# Inflation Rate                  0
# Date                            0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

col = "Unemployment Rate"

# Assuming lrData is a DataFrame with the columns 'Federal Funds Target Rate' and 'Inflation Rate'

# Convert the Series to NumPy arrays using .values and reshape if needed
x = lrData[col].values.reshape(-1, 1)
y = lrData['Inflation Rate'].values.reshape(-1, 1)

# Create a linear regression model
model = LinearRegression()
model.fit(x, y)

# Get the linear regression line (predicted values)
x_fit = np.linspace(x.min(), x.max(), 100).reshape((-1, 1))
y_fit = model.predict(x_fit)

# Plotting the scatter plot
plt.scatter(x, y, color='blue', label='Data points')

# Plotting the regression line
plt.plot(x_fit, y_fit, color='red', label='Regression line')

# Adding labels and title
plt.xlabel(col)
plt.ylabel('Inflation Rate')
plt.title('Scatter Plot with Regression Line')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

col = "Effective Federal Funds Rate"

# Assuming lrData is a DataFrame with the columns 'Federal Funds Target Rate' and 'Inflation Rate'

# Convert the Series to NumPy arrays using .values and reshape if needed
x = lrData[col].values.reshape(-1, 1)
y = lrData['Inflation Rate'].values.reshape(-1, 1)

# Create a linear regression model
model = LinearRegression()
model.fit(x, y)

# Get the linear regression line (predicted values)
x_fit = np.linspace(x.min(), x.max(), 100).reshape((-1, 1))
y_fit = model.predict(x_fit)

# Plotting the scatter plot
plt.scatter(x, y, color='blue', label='Data points')

# Plotting the regression line
plt.plot(x_fit, y_fit, color='red', label='Regression line')

# Adding labels and title
plt.xlabel(col)
plt.ylabel('Inflation Rate')
plt.title('Scatter Plot with Regression Line')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
lrData.set_index('Date', inplace=True)
lrData
# Out:
#             Year  Month  Day  Federal Funds Target Rate  \
# Date
# 1954-07-01  1954      7    1                   4.809181
# 1954-08-01  1954      8    1                   4.809181
# 1954-09-01  1954      9    1                   4.809181
# 1954-10-01  1954     10    1                   4.809181
# 1954-11-01  1954     11    1                   4.809181
# ...          ...    ...  ...                        ...
# 2016-12-14  2016     12   14                   1.000000
# 2017-01-01  2017      1    1                   1.000000
# 2017-02-01  2017      2    1                   1.000000
# 2017-03-01  2017      3    1                   1.000000
# 2017-03-16  2017      3   16                   1.000000
#
#             Effective Federal Funds Rate  Real GDP (Percent Change)  \
# Date
# 1954-07-01                          0.80                        4.6
# 1954-08-01                          1.22                        4.6
# 1954-09-01                          1.06                        4.6
# 1954-10-01                          0.85                        8.0
# 1954-11-01                          0.83                        8.0
# ...                                  ...                        ...
# 2016-12-14                          0.54                        1.9
# 2017-01-01                          0.65                        1.9
# 2017-02-01                          0.66                        1.9
# 2017-03-01                          0.66                        1.9
# 2017-03-16                          0.66                        1.9
#
#             Unemployment Rate  Inflation Rate
# Date
# 1954-07-01                5.8        3.710209
# 1954-08-01                6.0        3.710209
# 1954-09-01                6.1        3.710209
# 1954-10-01                5.7        3.710209
# 1954-11-01                5.3        3.710209
# ...                       ...             ...
# 2016-12-14                4.7        2.200000
# 2017-01-01                4.8        2.300000
# 2017-02-01                4.7        2.200000
# 2017-03-01                4.7        2.200000
# 2017-03-16                4.7        2.200000
#
# [904 rows x 8 columns]

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.sarima_model import SARIMA 
from statsmodels.tsa.statespace.sarimax import SARIMAX


from datetime import datetime, timedelta

# %% [markdown]
# <h1>
#
# SARIMAX model
#
# </h1>

# %%
# # Fit SARIMA model
# sarima_model = SARIMAX(lrData[forecastFor], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
# sarima_result = sarima_model.fit()

# %%
# Fit SARIMA model
# Create features (X) and target variables (y)
features = ['Date']  # Add other features as needed
target_columns = ['Federal Funds Target Rate',
       'Real GDP (Percent Change)', 'Unemployment Rate', 'Inflation Rate']

# Forecast future values
forecastFor = "Federal Funds Target Rate"

sarima_model = SARIMAX(lrData[forecastFor], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_result = sarima_model.fit()



forecast_steps = 150  # Assuming monthly data for 10 years (120 months)
future_dates = [lrData.index[-1] + timedelta(days=31 * i) for i in range(1, forecast_steps + 1)]

future_forecast = sarima_result.get_forecast(steps=forecast_steps)
forecast_index = pd.DatetimeIndex(future_dates)
forecast_series = pd.Series(future_forecast.predicted_mean.values, index=forecast_index)

# Visualize the forecast
plt.figure(figsize=(12, 6))
plt.plot(lrData[forecastFor], label='Historical Data')
plt.plot(forecast_series, label='Forecasted Data')
plt.title(forecastFor+" Predictions")
plt.xlabel('Date')
plt.ylabel(forecastFor)
plt.legend()
plt.show()
# Out:
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
sarima_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:          Federal Funds Target Rate   No. Observations:                  904
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                  30.261
# Date:                            Thu, 30 Nov 2023   AIC                            -50.522
# Time:                                    15:06:31   BIC                            -26.560
# Sample:                                         0   HQIC                           -41.364
#                                             - 904
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9305      0.053     17.522      0.000       0.826       1.035
# ma.L1         -0.8807      0.060    -14.796      0.000      -0.997      -0.764
# ar.S.L12      -0.0084      0.047     -0.177      0.860      -0.101       0.084
# ma.S.L12      -0.9980      0.369     -2.703      0.007      -1.722      -0.274
# sigma2         0.0517      0.018      2.812      0.005       0.016       0.088
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.49   Jarque-Bera (JB):           4421935.98
# Prob(Q):                              0.22   Prob(JB):                         0.00
# Heteroskedasticity (H): 102732112588952.92   Skew:                            14.50
# Prob(H) (two-sided):                  0.00   Kurtosis:                       346.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Create features (X) and target variables (y)
features = ['Date']  # Add other features as needed
target_columns = ['Federal Funds Target Rate',
       'Real GDP (Percent Change)', 'Unemployment Rate', 'Inflation Rate']

forecastFor = "Unemployment Rate"

sarima_model = SARIMAX(lrData[forecastFor], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_result = sarima_model.fit()
# Forecast future values



forecast_steps = 150  # Assuming monthly data for 10 years (120 months)
future_dates = [lrData.index[-1] + timedelta(days=31 * i) for i in range(1, forecast_steps + 1)]

future_forecast = sarima_result.get_forecast(steps=forecast_steps)
forecast_index = pd.DatetimeIndex(future_dates)
forecast_series = pd.Series(future_forecast.predicted_mean.values, index=forecast_index)

# Visualize the forecast
plt.figure(figsize=(12, 6))
plt.plot(lrData[forecastFor], label='Historical Data')
plt.plot(forecast_series, label='Forecasted Data')
plt.title(forecastFor+" Predictions")
plt.xlabel('Date')
plt.ylabel(forecastFor)
plt.legend()
plt.show()
# Out:
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Create features (X) and target variables (y)
features = ['Date']  # Add other features as needed
target_columns = ['Federal Funds Target Rate',
       'Real GDP (Percent Change)', 'Unemployment Rate', 'Inflation Rate']

forecastFor = "Inflation Rate"

sarima_model = SARIMAX(lrData[forecastFor], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_result = sarima_model.fit()
# Forecast future values



forecast_steps = 150  # Assuming monthly data for 10 years (120 months)
future_dates = [lrData.index[-1] + timedelta(days=31 * i) for i in range(1, forecast_steps + 1)]

future_forecast = sarima_result.get_forecast(steps=forecast_steps)
forecast_index = pd.DatetimeIndex(future_dates)
forecast_series = pd.Series(future_forecast.predicted_mean.values, index=forecast_index)

# Visualize the forecast
plt.figure(figsize=(12, 6))
plt.plot(lrData[forecastFor], label='Historical Data')
plt.plot(forecast_series, label='Forecasted Data')
plt.title(forecastFor+" Predictions")
plt.xlabel('Date')
plt.ylabel(forecastFor)
plt.legend()
plt.show()
# Out:
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Create features (X) and target variables (y)
features = ['Date']  # Add other features as needed
target_columns = ['Federal Funds Target Rate',
       'Real GDP (Percent Change)', 'Unemployment Rate', 'Inflation Rate']

forecastFor = "Real GDP (Percent Change)"

sarima_model = SARIMAX(lrData[forecastFor], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_result = sarima_model.fit()
# Forecast future values



forecast_steps = 150  # Assuming monthly data for 10 years (120 months)
future_dates = [lrData.index[-1] + timedelta(days=31 * i) for i in range(1, forecast_steps + 1)]

future_forecast = sarima_result.get_forecast(steps=forecast_steps)
forecast_index = pd.DatetimeIndex(future_dates)
forecast_series = pd.Series(future_forecast.predicted_mean.values, index=forecast_index)

# Visualize the forecast
plt.figure(figsize=(12, 6))
plt.plot(lrData[forecastFor], label='Historical Data')
plt.plot(forecast_series, label='Forecasted Data')
plt.title(forecastFor+" Predictions")
plt.xlabel('Date')
plt.ylabel(forecastFor)
plt.legend()
plt.show()
# Out:
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Patron\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
